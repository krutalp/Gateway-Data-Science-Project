# %% [markdown]
# ## Classification of breast cancer histopathology images
#
# Anusha, Krutal, Gracelyn
#
# 1. Data Processing
#     Data organization and labeling

# %%
# Import data and read one image
import matplotlib.pyplot as plt
import numpy as np
import PIL as pil
from PIL import Image

#Read the image#
data = Image.open("TrainTest\Benign\SOB_B_A-14-22549AB-40-002.png")
image_array = np.array(data)

image_array
print(image_array.shape) # 400, 700, 3 3 rgb channels 
fig_1 = plt.figure(figsize = (8,8), facecolor='w',edgecolor='k')
plt.imshow(image_array)
# Out:
# (460, 700, 3)
